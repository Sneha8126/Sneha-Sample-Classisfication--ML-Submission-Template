# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha8126/Sneha-Sample-Classisfication--ML-Submission-Template/blob/main/Sneha_Sample_Classisfication_ML_Submission_Template.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - Classification
# ##### **Contribution**    - Individual
#
# Name : Sneha
#
# Branch : CSE - C
#
# Roll Number : 51420802724

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Employee attrition is a significant challenge for organizations as it leads to increased recruitment costs, reduced productivity, and loss of experienced employees. This project aims to analyze employee demographic, job-related, and workplace factors to identify the key reasons behind attrition. By using the Employee Attrition dataset, the goal is to predict whether an employee is likely to Stay or Leave the company. The insights gained from this analysis can help organizations improve employee retention and make informed HR decisions.**

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Load Dataset
df = pd.read_csv('/content/drive/MyDrive/train.csv')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#    Employee ID  Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0         8410   31    Male                19   Education            5390
# 1        64756   59  Female                 4       Media            5534
# 2        30257   24  Female                10  Healthcare            8159
# 3        65791   36  Female                 7   Education            3989
# 4        65026   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
#
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (59598, 24)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59598 entries, 0 to 59597
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Employee ID               59598 non-null  int64
#  1   Age                       59598 non-null  int64
#  2   Gender                    59598 non-null  object
#  3   Years at Company          59598 non-null  int64
#  4   Job Role                  59598 non-null  object
#  5   Monthly Income            59598 non-null  int64
#  6   Work-Life Balance         59598 non-null  object
#  7   Job Satisfaction          59598 non-null  object
#  8   Performance Rating        59598 non-null  object
#  9   Number of Promotions      59598 non-null  int64
#  10  Overtime                  59598 non-null  object
#  11  Distance from Home        59598 non-null  int64
#  12  Education Level           59598 non-null  object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()
print(f"Number of Duplicate Rows : {duplicate_count}")
# Out:
# Number of Duplicate Rows : 0

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(df.isnull().sum())
# Out:
# Employee ID                 0
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %%
# Visualizing the missing values
plt.figure(figsize=(14, 8))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)

plt.title('Heatmap of Missing Values (Yellow = Missing Data)')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# * The dataset contains 59,598 employee records and 24 columns, making it a large dataset suitable for data analysis and machine learning.
#
# * It consists of both numerical and categorical variables, providing information about employee demographics, job roles, work environment, and company-related factors.
#
# * The target variable is Attrition, which indicates whether an employee has **Stayed** or **Left** the company.
#
# * The dataset includes a unique identifier (Employee ID), which is useful for identifying records but does not contribute to prediction and can be removed during preprocessing.
#
# * The dataset has good data quality, with **no missing (null) values** present in any of the columns. Therefore, missing value imputation is not required.
#
# * **No duplicate records were found in the dataset**, ensuring that each employee record is unique and preventing bias during analysis.
#
# * The dataset contains several categorical features such as Gender, Job Role, Marital Status, and Overtime, which require encoding before they can be used for analysis.
#
# * The numerical features have different ranges and units, so scaling may be required depending on the analysis or algorithm being used.
#
# * The dataset represents various aspects of an employee's profile, including personal information, job-related details, company environment, and career progression, making it comprehensive for attrition analysis.
#
# * Overall, the dataset is clean, structured, and well-organized, making it suitable for exploratory data analysis (EDA), feature engineering, and predictive analytics.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['Employee ID', 'Age', 'Gender', 'Years at Company', 'Job Role',
#        'Monthly Income', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Number of Promotions', 'Overtime',
#        'Distance from Home', 'Education Level', 'Marital Status',
#        'Number of Dependents', 'Job Level', 'Company Size', 'Company Tenure',
#        'Remote Work', 'Leadership Opportunities', 'Innovation Opportunities',
#        'Company Reputation', 'Employee Recognition', 'Attrition'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#         Employee ID           Age  Years at Company  Monthly Income  \
# count  59598.000000  59598.000000      59598.000000    59598.000000
# mean   37227.118729     38.565875         15.753901     7302.397983
# std    21519.150028     12.079673         11.245981     2151.457423
# min        1.000000     18.000000          1.000000     1316.000000
# 25%    18580.250000     28.000000          7.000000     5658.000000
# 50%    37209.500000     39.000000         13.000000     7354.000000
# 75%    55876.750000     49.000000         23.000000     8880.000000
# max    74498.000000     59.000000         51.000000    16149.000000
#
#        Number of Promotions  Distance from Home  Number of Dependents  \
# count          59598.000000        59598.000000          59598.000000
# mean               0.832578           50.007651              1.648075
# std                0.994991           28.466459              1.555689
# min                0.000000            1.000000              0.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# | **Variable Name**            | **Description**                                                                                                           |
# | ---------------------------- | ------------------------------------------------------------------------------------------------------------------------- |
# | **Employee ID**              | A unique identifier assigned to each employee. It is used only to identify records and does not contribute to prediction. |
# | **Age**                      | Age of the employee in years.                                                                                             |
# | **Gender**                   | Gender of the employee (Male/Female).                                                                                     |
# | **Years at Company**         | Total number of years the employee has worked in the company.                                                             |
# | **Job Role**                 | The employee's job designation or position within the organization.                                                       |
# | **Monthly Income**           | Monthly salary earned by the employee.                                                                                    |
# | **Work-Life Balance**        | Employee's satisfaction with the balance between work and personal life.                                                  |
# | **Job Satisfaction**         | Overall satisfaction level of the employee with their job.                                                                |
# | **Performance Rating**       | Employee's performance evaluation score assigned by the organization.                                                     |
# | **Number of Promotions**     | Total number of promotions received by the employee.                                                                      |
# | **Overtime**                 | Indicates whether the employee regularly works overtime (Yes/No).                                                         |
# | **Distance from Home**       | Distance between the employee's home and workplace.                                                                       |
# | **Education Level**          | Highest educational qualification attained by the employee.                                                               |
# | **Marital Status**           | Marital status of the employee (Single, Married, etc.).                                                                   |
# | **Number of Dependents**     | Number of family members financially dependent on the employee.                                                           |
# | **Job Level**                | Employee's position or seniority level within the company.                                                                |
# | **Company Size**             | Size of the organization where the employee works (Small, Medium, Large).                                                 |
# | **Company Tenure**           | Total duration for which the employee has been associated with the company.                                               |
# | **Remote Work**              | Indicates whether the employee works remotely or on-site.                                                                 |
# | **Leadership Opportunities** | Availability of leadership or career advancement opportunities within the company.                                        |
# | **Innovation Opportunities** | Availability of opportunities for innovation and creative contributions.                                                  |
# | **Company Reputation**       | Employee's perception of the company's reputation and image.                                                              |
# | **Employee Recognition**     | Indicates whether the employee receives recognition or appreciation for their work.                                       |
# | **Attrition**                | **Target Variable** indicating whether the employee **Stayed** or **Left** the company.                                   |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()
# Out:
# Employee ID                 59598
# Age                            42
# Gender                          2
# Years at Company               51
# Job Role                        5
# Monthly Income               9569
# Work-Life Balance               4
# Job Satisfaction                4
# Performance Rating              4
# Number of Promotions            5
# Overtime                        2
# Distance from Home             99
# Education Level                 5
# Marital Status                  3
# Number of Dependents            7
# Job Level                       3
# Company Size                    3
# Company Tenure                127
# Remote Work                     2
# Leadership Opportunities        2
# Innovation Opportunities        2
# Company Reputation              4
# Employee Recognition            4
# Attrition                       2
# dtype: int64

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Check missing values
null_values = df.isnull().sum().sum()
print(f"The number of Null values : {null_values}")

# Check duplicated rows
duplicate_count = df.duplicated().sum()
print(f"The Number of Duplicated Rows : {duplicate_count}")

# Drop employee ID
df.drop('Employee ID',axis=1,inplace=True)

# Verify dataset
df.head()
# Out:
# The number of Null values : 0
# The Number of Duplicated Rows : 0
#    Age  Gender  Years at Company    Job Role  Monthly Income  \
# 0   31    Male                19   Education            5390
# 1   59  Female                 4       Media            5534
# 2   24  Female                10  Healthcare            8159
# 3   36  Female                 7   Education            3989
# 4   56    Male                41   Education            4821
#
#   Work-Life Balance Job Satisfaction Performance Rating  Number of Promotions  \
# 0         Excellent           Medium            Average                     2
# 1              Poor             High                Low                     3
# 2              Good             High                Low                     0
# 3              Good             High               High                     1
# 4              Fair        Very High            Average                     0
#
# ...

# %% [markdown]
# #### What all manipulations have you done and insights you found?

# %% [markdown]
# ##### Manipulations
# * **Checked for missing (null) values** across all columns and confirmed that the dataset contains no missing values, so no imputation was required.
#
# * **Checked for duplicate records** and verified that the dataset contains** no duplicate entries**, ensuring data consistency and reliability.
#
# * **Dropped the Employee ID column** because it is a unique identifier and does not provide predictive information for employee attrition analysis.
#
# ##### Insights
# * **The dataset is complete and of high quality**, as it contains no missing values, reducing the need for extensive data cleaning.
#
# * **No duplicate records were found**, indicating that each employee record is unique and preventing repeated observations from affecting the analysis.
#
# * The **Employee ID column** does not contain analytical value and was **removed** because it serves only as a unique identifier.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
attrition_counts = df['Attrition'].value_counts()

# Pie Chart
plt.figure(figsize=(7,7))

plt.pie(
    attrition_counts,
    labels=attrition_counts.index,
    autopct='%1.1f%%',
    startangle=90,
    explode=[0.03, 0.03],   # Slightly separate both slices
    shadow=True
)

plt.title('Distribution of Employee Attrition', fontsize=15)

plt.axis('equal')   # Makes the pie chart circular

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * I selected a **pie chart** because it is an effective way to visualize the proportion of employees who **stayed and left the company**.
# * It provides a quick overview of the target variable distribution and helps determine whether the dataset is **balanced or imbalanced**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The chart shows that the number of employees who Stayed is slightly higher than those who Left the company.
#
# * The difference between the two classes is relatively small, indicating that the dataset is **reasonably balanced** and does not suffer from severe class imbalance.
#
# * A significant number of employees have left the organization, highlighting that employee attrition is an important business concern that requires further investigation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, the insights can create a positive business impact by helping the HR department understand the overall employee attrition level and prioritize retention strategies accordingly.
#
# * Since a large number of employees have left the organization, the company can investigate the underlying causes and implement targeted improvements in areas such as employee satisfaction, career development, and workplace policies.
#
# * A high attrition rate can negatively impact business growth because replacing experienced employees increases recruitment, onboarding, and training costs.
#
# * Frequent employee turnover can also reduce productivity, disrupt team collaboration, and lead to the loss of valuable skills and organizational knowledge, ultimately affecting the company's overall performance and profitability.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# Set style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x='Attrition',
    y='Age',
    palette='Set2'
)

plt.title('Age Distribution by Employee Attrition', fontsize=16)
plt.xlabel('Employee Attrition', fontsize=12)
plt.ylabel('Age (Years)', fontsize=12)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A **box plot** was chosen because Age is a numerical variable and Attrition is a categorical variable. This visualization is ideal for comparing the age distribution of employees who Stayed and Left.
# * It summarizes the data by displaying the **median, interquartile range (IQR), overall spread, and potential outliers**, making it easier to identify differences in age between the two employee groups.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The median age of employees who Stayed and those who Left is nearly the same, indicating that both groups have a similar age distribution.
#
# * The interquartile range (IQR) is also very similar for both categories, suggesting that the variability in employee age does not differ significantly between employees who stayed and those who left.
#
# * Both groups have a comparable age range, extending from approximately 18 to 59 years, showing that attrition occurs across employees of different ages.
#
# * There are no noticeable outliers or extreme differences between the two groups, indicating a fairly consistent age distribution.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, these insights can positively impact the business by helping HR understand the organization's workforce age composition and design age-specific engagement, training, and career development programs.
#
# * The balanced age distribution indicates that the company has a healthy mix of young, mid-career, and experienced employees, which supports knowledge sharing and workforce stability.
#
# * No direct negative growth is observed from this chart alone, as the age distribution appears balanced. However, if future analysis shows that a particular age group has a significantly higher attrition rate, it may indicate challenges related to career growth, employee engagement, or retention strategies for that group.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# Set style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(7,5))

ax = sns.countplot(
    data=df,
    x='Gender',
    hue='Attrition',
    palette='viridis'
)

# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=9)

plt.title('Gender vs Employee Attrition', fontsize=16)
plt.xlabel('Gender', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)

plt.legend(title='Attrition')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A count plot is chosen because Gender is a categorical variable, and the objective is to compare employee attrition between male and female employees.
#
# * This chart clearly shows the number of employees who Stayed and Left within each gender, making it easier to identify whether gender has any noticeable relationship with employee attrition.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The organization has **more male employees than female employees**, as indicated by the higher total count of male employees.
#
# * Among **male employees**, the number of employees who **Stayed** is considerably higher than those who **Left**, suggesting better employee retention within this group.
#
# * Among **female employees**, the number of employees who **Left** is slightly higher than those who **Stayed**, indicating comparatively higher attrition among female employees.
#
# * The difference in attrition patterns between male and female employees suggests that gender may have some influence on employee retention, although additional workplace factors should also be examined before drawing final conclusions.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, these insights can create a positive business impact by helping HR identify differences in employee retention across genders and develop more inclusive retention strategies.
# The comparatively higher attrition among female employees suggests that the organization should further investigate factors such as work-life balance, flexible work arrangements, career advancement opportunities, and workplace support programs.
#
# * The higher retention among male employees indicates that existing policies may be effective for a large portion of the workforce, but improvements may still be needed to enhance retention across all employee groups.
#
# * A higher attrition rate among female employees may negatively impact business growth by reducing workforce diversity, increasing recruitment and training costs, and potentially affecting team stability and organizational performance.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

# Set style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8,5))

ax = sns.countplot(
    data=df,
    x='Marital Status',
    hue='Attrition',
    palette='pastel'
)

# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=9)

plt.title('Marital Status vs Employee Attrition', fontsize=16)
plt.xlabel('Marital Status', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)

plt.legend(title='Attrition')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A count plot is chosen because Marital Status is a categorical variable. This visualization clearly compares the number of employees who Stayed and Left across different marital status categories.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Married employees** represent the largest group in the organization, and the number of employees who Stayed is significantly higher than those who Left, indicating strong employee retention within this group.
#
# * **Single employees** show the opposite trend, where the number of employees who Left is considerably higher than those who Stayed, suggesting that this group experiences the highest employee attrition.
#
# * **Divorced employees** form the smallest group in the dataset, and they also exhibit relatively lower attrition compared to the other marital status categories.
#
# * The chart indicates that marital status appears to have a noticeable relationship with employee attrition, with single employees showing a greater tendency to leave the organization than married or divorced employees.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, these insights can create a positive business impact by helping HR identify employee groups that are more likely to leave the organization and design targeted retention strategies.
#
# * Since single employees have the highest attrition, the organization can investigate factors such as career growth opportunities, work-life balance, compensation, job satisfaction, and employee engagement to improve retention within this group.
#
# * The high retention among married employees suggests that existing organizational policies may be supporting long-term employee commitment, and these practices can be strengthened further.
#
# * A high attrition rate among single employees may negatively impact business growth, as frequent employee turnover increases recruitment and training costs, reduces productivity, and leads to the loss of skilled employees.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# Set style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(9,5))

ax = sns.countplot(
    data=df,
    x='Education Level',
    hue='Attrition',
    palette='Set3'
)

# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=9)

plt.title('Education Level vs Employee Attrition', fontsize=16)
plt.xlabel('Education Level', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)

plt.legend(title='Attrition')
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A count plot is chosen because Education Level is a categorical variable. This chart enables a clear comparison of employees who Stayed and Left across different education levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Employees with a **Bachelor's Degree** represent the largest group in the organization, and they also have the highest number of employees who both Stayed and Left.
#
# * Across most education levels, including **Associate Degree, Master's Degree, Bachelor's Degree, and High School**, the number of employees who Stayed is slightly higher than those who Left, indicating relatively good employee retention.
#
# * Employees with a PhD have the lowest representation in the organization, and only a small number of them left the company, suggesting comparatively stronger retention within this group.
#
# * The differences between employees who stayed and left are relatively small for most education levels, indicating that **education level alone is not a strong predictor of employee attrition**.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, these insights can create a positive business impact by helping HR understand employee retention across different educational backgrounds and develop more effective workforce planning strategies.
#
# * Since employees with a Bachelor's Degree form the largest workforce, improving engagement, career development, and recognition programs for this group can have a significant impact on reducing overall attrition.
#
# * The strong retention observed among employees with PhD qualifications suggests that advanced career opportunities and specialized roles may contribute to employee commitment.
#
# * A higher number of employees leaving from the Bachelor's Degree group may negatively impact business growth, as this group represents the largest share of the workforce. Losing a large number of employees from this category can increase recruitment costs, reduce productivity, and create skill shortages.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# Set style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x='Attrition',
    y='Monthly Income',
    palette='Dark2'
)

plt.title('Monthly Income by Employee Attrition', fontsize=16)
plt.xlabel('Employee Attrition', fontsize=12)
plt.ylabel('Monthly Income', fontsize=12)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A box plot was selected because it is an effective visualization for comparing the distribution of a numerical variable (Monthly Income) across two categories of the target variable (Stayed and Left).

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The median monthly income of employees who Stayed and those who Left is very similar, indicating that salary levels are comparable between the two groups.
#
# * Both groups contain several high-income outliers, showing that employees with higher salaries are present in both attrition categories.
#
# * The significant overlap between the two box plots suggests that monthly income alone does not strongly differentiate employees who leave from those who stay.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, these insights can create a positive business impact by helping management understand that increasing salaries alone may not be sufficient to reduce employee attrition.
#
# * Since salary distributions are similar for both employees who stayed and those who left, HR should investigate additional factors that contribute to employee turnover instead of relying only on compensation.
#
# * A negative business impact may occur if the organization assumes that salary is the only reason employees leave. Investing heavily in salary increases without addressing workplace satisfaction or growth opportunities may not significantly improve employee retention.
#
# * These insights encourage a balanced retention strategy that combines competitive compensation with a positive work environment, ultimately improving employee satisfaction and organizational performance.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# Set style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8,5))

ax = sns.countplot(
    data=df,
    x='Job Level',
    hue='Attrition',
    palette='Paired'
)

# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=9)

plt.title('Job Level vs Employee Attrition', fontsize=16)
plt.xlabel('Job Level', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)

plt.legend(title='Attrition')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A grouped bar chart (count plot) was selected because Job Level is a categorical variable, while Attrition is also categorical.
#
# * This chart provides a clear side-by-side comparison of employees who Stayed and Left at each job level, making it easy to identify which level experiences higher employee retention or attrition.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Entry-level employees have the highest number of employees who left (15,082), which is greater than the number who stayed (8,785). This indicates that attrition is highest among employees at the beginning of their careers.
#
# * Senior-level employees show the highest retention, with 9,545 employees staying compared to only 2,433 employees leaving. This suggests that employees at higher job levels are more likely to remain with the organization.
#
# * At the Mid-level, the number of employees who stayed (12,930) is higher than those who left (10,823), indicating moderate employee retention.
#
# * The chart shows a clear pattern that employee retention improves as job level increases, while attrition is more concentrated at lower job levels.
#
# * These findings suggest that career progression and advancement opportunities may play an important role in improving employee retention.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, these insights can create a positive business impact by helping HR identify that entry-level employees require greater attention in terms of training, mentoring, career development, and employee engagement.
#
# * The strong retention observed among senior-level employees indicates that career growth and higher responsibilities contribute to long-term employee commitment and organizational stability.
#
# * Organizations can improve retention by establishing clear promotion pathways, skill development programs, and regular performance feedback for employees at lower job levels.
#
# * The high attrition among entry-level employees may negatively impact business growth, as it increases recruitment, onboarding, and training costs while reducing productivity due to frequent employee turnover.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
order = ['Mid', 'Senior','Entry']

plt.figure(figsize=(9,5))

sns.boxplot(
    data=df,
    x='Job Level',
    y='Monthly Income',
    order=order,
    palette='Set2'
)

plt.title('Monthly Income by Job Level', fontsize=16, fontweight='bold')
plt.xlabel('Job Level')
plt.ylabel('Monthly Income')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This box plot was selected to compare the distribution of monthly income across different job levels (Entry, Mid, and Senior).
#
# * It clearly displays the median, spread (IQR), and outliers, making it easier to understand salary variations within each job level.
#
# * The chart helps determine whether employees receive higher salaries as they progress to higher job levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The median monthly income is relatively similar across Entry, Mid, and Senior job levels, indicating only a slight increase with higher job levels in this dataset.
#
# * All three job levels show a wide range of monthly incomes and several high-income outliers, suggesting salary variation even within the same job level.
#
# * The overlapping income distributions indicate that job level alone does not fully explain salary differences, and other factors may also influence employee income.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The insights can help HR evaluate whether the salary structure is fair and aligned with career progression, supporting better compensation planning.
#
# * The limited salary difference between job levels may reduce employee motivation for promotions and career growth, potentially affecting retention.
#
# * Reviewing salary policies and ensuring competitive compensation across job levels can improve employee satisfaction, engagement, and long-term retention.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# Set style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x='Attrition',
    y='Years at Company',
    palette='Spectral'
)

plt.title('Years at Company by Employee Attrition', fontsize=16)
plt.xlabel('Employee Attrition')
plt.ylabel('Years at Company')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A box plot was chosen because Years at Company is a continuous numerical variable, while Attrition is a categorical variable.
#
# * This chart is ideal for comparing the distribution of employee tenure between those who Stayed and those who Left.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The median Years at Company is slightly higher for employees who Stayed than for those who Left, indicating that employees with longer tenure tend to remain with the organization.
#
# * The interquartile range (IQR) of both groups is fairly similar, suggesting that the variation in years of service is comparable for employees who stayed and those who left.
#
# * Most employees in both categories have worked for approximately 6 to 24 years, indicating that the majority of the workforce falls within the mid-tenure range.
#
# * Both groups contain several high-tenure outliers (around 46–51 years), showing that a small number of employees have remained with the organization for a very long time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, these insights can create a positive business impact by helping HR understand how employee tenure relates to retention and workforce stability.
#
# * The slightly higher median tenure among employees who stayed indicates that retaining employees over the long term can contribute to organizational stability, knowledge retention, and improved productivity.
#
# * HR can focus on strengthening onboarding, mentoring, and career development programs to encourage employees to remain with the organization for longer periods.
#
# * A higher turnover among employees with shorter tenure may negatively impact business growth, as frequent employee departures increase recruitment, onboarding, and training costs while reducing team continuity and productivity.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
plt.figure(figsize=(14,6))

sns.boxplot(
    data=df,
    x='Years at Company',
    y='Monthly Income',
    hue='Years at Company',
    palette='Set2',
    showfliers=False,
    legend=False
)

plt.title('Monthly Income Distribution by Years at Company', fontsize=16, fontweight='bold')
plt.xlabel('Years at Company', fontsize=12)
plt.ylabel('Monthly Income', fontsize=12)

plt.xticks(rotation=90)
plt.grid(axis='y', linestyle='--', alpha=0.4)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This box plot was chosen to compare the distribution of monthly income across different years of service in the company.
#
# * It effectively displays the median, interquartile range (IQR), and variability of salaries for each experience level.
#
# * The chart helps identify whether employees' salaries change as their years at the company increase.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * The median monthly income remains fairly consistent across most years at the company, indicating that salary growth with tenure is not very significant in this dataset.
#
# * Salary distributions are quite similar across different experience levels, suggesting that years at the company alone do not strongly influence monthly income.
#
# * Most experience groups show a wide range of salaries, indicating that other factors such as job level, role, promotions, or performance also affect employee income.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * These insights help HR evaluate whether the salary progression policy is aligned with employee experience, supporting fair compensation planning.
#
# * The limited increase in salary with increasing years at the company may reduce employee motivation and long-term retention if employees feel their experience is not adequately rewarded.
#
# * Organizations can use these findings to review promotion and compensation policies, ensuring experienced employees receive appropriate career growth and salary progression.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# Set style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(8,5))

ax = sns.countplot(
    data=df,
    x='Number of Promotions',
    hue='Attrition',
    palette='magma'
)


# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=9)



plt.title('Number of Promotions vs Employee Attrition', fontsize=16)
plt.xlabel('Number of Promotions', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)

plt.xticks([0,1,2,3,4])
plt.legend(title='Attrition')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A grouped bar chart (count plot) was chosen because Number of Promotions is a discrete numerical variable with only five categories (0–4), while Attrition is a categorical variable.
#
# * This chart clearly compares the number of employees who Stayed and Left at each promotion level, making it easy to identify whether promotion opportunities are associated with employee retention.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Employees with 0 promotions form the largest group in the organization, and this group also has the highest number of employees who Left, indicating that a lack of promotions may contribute to higher employee turnover.
#
# * As the number of promotions increases, the number of employees generally decreases, showing that fewer employees receive multiple promotions.
#
# * Employees with 3 or 4 promotions are much more likely to Stay than Leave, suggesting that career advancement is associated with better employee retention.
#
# * The gap between employees who Stayed and Left becomes wider at higher promotion levels, indicating that employees who receive more promotions are less likely to leave the organization.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, these insights can create a positive business impact by highlighting the importance of fair and timely promotion opportunities in improving employee retention.
#
# * Organizations can strengthen employee engagement by implementing transparent promotion policies, regular performance evaluations, and well-defined career development pathways.
#
# * Employees who receive promotions are more likely to feel recognized and motivated, which can improve job satisfaction, productivity, and long-term commitment to the organization.
#
# * A large number of employees with no promotions may negatively impact business growth, as limited career progression can reduce employee motivation, increase dissatisfaction, and lead to higher attrition. This can result in increased recruitment costs, loss of experienced talent, and reduced organizational productivity.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# Set style
sns.set_theme(style="whitegrid")
plt.figure(figsize=(7,5))

ax = sns.countplot(
    data=df,
    x='Overtime',
    hue='Attrition',
    palette='Pastel1'
)

# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.title('Overtime vs Employee Attrition', fontsize=16)
plt.xlabel('Overtime', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)

plt.legend(title='Attrition')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A grouped bar chart (count plot) was selected because both Overtime and Attrition are categorical variables.
#
# * This chart allows a direct comparison of employees who Stayed and Left based on whether they worked overtime.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Employees who do not work overtime form the largest group in the organization, and the number of employees who Stayed (21,835) is higher than those who Left (18,313).
#
# * Among employees who work overtime, the number of employees who Left (10,025) is slightly higher than those who Stayed (9,425), indicating comparatively higher attrition in this group.
#
# * The chart suggests that employees working overtime are more likely to leave the organization than employees who do not work overtime.
#
# * The difference between the Stayed and Left categories changes noticeably with overtime status, indicating that overtime may influence employee retention.
#
# * Overall, the chart indicates that overtime is an important workplace factor associated with employee attrition and should be considered when developing retention strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, these insights can create a positive business impact by helping management understand the effect of overtime on employee retention and overall workforce well-being.
#
# * Organizations can reduce employee turnover by implementing balanced workloads, effective resource planning, flexible work schedules, and employee wellness initiatives to minimize excessive overtime.
#
# * Reducing unnecessary overtime can improve employee satisfaction, lower stress levels, increase productivity, and strengthen long-term employee commitment.
#
# * Higher attrition among employees who work overtime may negatively impact business growth, as excessive workload can lead to employee burnout, reduced morale, increased recruitment and training costs, and the loss of experienced employees.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
plt.figure(figsize=(8,5))

order = ['Poor', 'Fair', 'Good', 'Excellent']

ax = sns.countplot(
    data=df,
    x='Work-Life Balance',
    hue='Attrition',
    order=order,
    palette='Accent'
)

# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.title('Work-Life Balance vs Employee Attrition', fontsize=16)
plt.xlabel('Work-Life Balance', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)

plt.legend(title='Attrition')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A count plot with hue='Attrition' was chosen because Work-Life Balance is a categorical variable, and the objective is to compare the number of employees who Stayed and Left across different work-life balance levels.
# * This visualization clearly highlights how employee retention and attrition vary with employees' perceived work-life balance, helping to identify whether maintaining a healthy balance influences employee turnover.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Employees with **Good and Excellent** work-life balance show **higher retention**, as the number of employees who Stayed is significantly greater than those who Left.
#
# * Employees reporting **Poor and Fair** work-life balance exhibit **higher attrition**, with more employees leaving the organization than staying.
#
# * The Good work-life balance category contains the largest number of retained employees, suggesting that a healthy balance between work and personal life is associated with improved employee retention.
#
# * The Fair work-life balance category records the highest number of employees who left, indicating that even a moderate imbalance in work-life conditions may increase the likelihood of employee turnover.
#
# * Overall, the chart suggests a strong relationship between work-life balance and employee attrition, making it one of the key factors that may influence an employee's decision to remain with or leave the organization.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * **Yes, these insights can create a positive business impact** by helping organizations recognize the importance of maintaining a healthy work-life balance to improve employee retention.
#
# * HR can introduce initiatives such as flexible working hours, remote work options, employee wellness programs, and workload management to improve work-life balance and increase employee satisfaction.
#
# * Improving work-life balance can enhance employee engagement, reduce stress, increase productivity, and strengthen long-term workforce stability.
#
# * **Poor and Fair work-life balance may lead to negative business growth** because higher employee turnover increases recruitment and training costs, disrupts team performance, and results in the loss of experienced employees.

# %% [markdown]
# #### Chart - 14

# %%
# Chart - 14 visualization code
plt.figure(figsize=(8,5))

order = ['Low', 'Medium', 'High', 'Very High']

ax = sns.countplot(
    data=df,
    x='Job Satisfaction',
    hue='Attrition',
    order=order,
    palette='viridis'
)

# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.title('Job Satisfaction vs Employee Attrition', fontsize=16)
plt.xlabel('Job Satisfaction', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)

plt.legend(title='Attrition')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * A grouped bar chart (count plot) was chosen because Job Satisfaction is a categorical variable, and Attrition is also categorical.
#
# *  This visualization enables a direct comparison of employees who Stayed and Left across different job satisfaction levels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Employees with High Job Satisfaction represent the largest group in the organization, with 16,290 employees staying compared to 13,489 employees leaving, indicating relatively better employee retention in this category.
#
# * Employees with Low Job Satisfaction have more employees leaving (3,088) than staying (2,803), suggesting that low satisfaction is associated with a higher likelihood of employee attrition.
#
# * In the Medium Job Satisfaction category, the number of employees who Stayed (6,461) is higher than those who Left (5,356), indicating moderate employee retention.
#
# * Employees with Very High Job Satisfaction also show a higher number of employees leaving (6,405) than staying (5,706). This suggests that although satisfaction is important, it is not the only factor influencing employee attrition, and other workplace factors may also contribute to employees leaving.
#
# * Overall, the chart indicates that job satisfaction influences employee retention, but it should be analyzed together with factors such as career growth, overtime, work-life balance, salary, and promotion opportunities.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Yes, these insights can create a positive business impact by helping organizations identify employee satisfaction levels that require greater attention to improve retention.
#
# * Management can improve employee satisfaction by providing career development opportunities, recognition programs, constructive feedback, and a supportive work environment.
#
# * The strong retention observed among employees with High Job Satisfaction suggests that maintaining a positive workplace culture can contribute to improved employee commitment and organizational performance.
#
# * Higher attrition among employees with Low Job Satisfaction may negatively impact business growth, as dissatisfied employees are more likely to leave the organization, increasing recruitment costs, reducing productivity, and causing the loss of experienced talent.
#
# * The fact that attrition is also relatively high among employees with Very High Job Satisfaction indicates that satisfaction alone may not fully explain employee turnover. Organizations should investigate additional factors such as compensation, workload, promotion opportunities, and work-life balance to develop more effective retention strategies

# %% [markdown]
# #### Chart - 15

# %%
# Chart - 15 visualization code

plt.figure(figsize=(9,5))

sns.countplot(
    data=df,
    x='Job Satisfaction',
    hue='Work-Life Balance',
    palette='Set2'
)

plt.title('Job Satisfaction vs Work-Life Balance', fontsize=16, fontweight='bold')
plt.xlabel('Job Satisfaction', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)

plt.legend(title='Work-Life Balance')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This chart was chosen to analyze the relationship between job satisfaction and work-life balance, two important factors that influence employee well-being.
#
# * It provides a clear comparison of different work-life balance levels across each job satisfaction category.
#
# * The chart helps identify whether employees with a better work-life balance also report higher job satisfaction.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Employees with Good work-life balance have the highest levels of High and Very High job satisfaction, indicating a strong positive relationship.
#
# * Employees with Poor work-life balance are comparatively fewer in the High and Very High satisfaction categories, suggesting that poor work-life balance may reduce job satisfaction.
#
# * The chart indicates that maintaining a healthy work-life balance is associated with greater employee satisfaction and a more positive work experience.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Improving work-life balance through flexible work policies, manageable workloads, and employee wellness initiatives can increase job satisfaction, employee engagement, and retention.
#
# * Poor work-life balance may lead to lower job satisfaction, reduced productivity, increased stress, and a higher risk of employee attrition.
#
# * These insights help organizations design HR policies that improve both employee well-being and long-term organizational performance.

# %% [markdown]
# #### Chart - 16

# %%
# Chart - 16 visualization code


plt.figure(figsize=(8,5))

ax = sns.countplot(
    data=df,
    x='Remote Work',
    hue='Attrition',
    palette='inferno'
)

# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.title('Employee Attrition by Remote Work', fontsize=15)
plt.xlabel('Remote Work', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)
plt.legend(title='Attrition')

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This chart is chosen to examine whether **remote work has an impact** on employee attrition.
#
# * It provides a clear comparison between employees who **stayed and left based on remote work **availability.
#
# * The chart helps identify whether offering remote work can improve employee retention and **supports HR decision-making**.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Employees without remote work have a significantly higher number of attrition cases than employees with remote work.
#
# * Employees who have remote work opportunities are more likely to stay with the company, indicating better retention.
#
# * The chart suggests that remote work may contribute to lower attrition by improving employee flexibility and work-life balance.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Expanding remote or hybrid work policies can improve employee retention, reduce recruitment costs, and increase workforce stability.
#
# * The high attrition among employees without remote work indicates a potential risk of losing skilled talent if workplace flexibility is not provided.
#
# * These insights help organizations design better retention strategies and create a more employee-friendly work environment.

# %% [markdown]
# #### Chart - 17

# %%
# Chart - 17 visualization code


plt.figure(figsize=(9,5))

ax = sns.countplot(
    data=df,
    x='Company Reputation',
    hue='Attrition',
    palette='plasma'
)

# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.title('Company Reputation vs Employee Attrition', fontsize=15)
plt.xlabel('Company Reputation', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)
plt.legend(title='Attrition')

plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This chart was chosen to analyze how **company reputation influences employee attrition** across different **reputation levels**.
#
# * It provides a **clear comparison of employees who stayed and left** in each company reputation category.
#
# * The chart helps identify whether improving the company's reputation can enhance employee retention and reduce turnover.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Companies with an Excellent reputation have more employees staying than leaving, indicating better employee retention.
#
# * Companies with Poor and Fair reputations show relatively higher attrition, suggesting that weaker company reputation may contribute to employees leaving.
#
# * A positive company reputation appears to be associated with higher employee retention and lower turnover.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Improving company reputation can increase employee trust, satisfaction, and retention while reducing recruitment and training costs.
#
# * Higher attrition in organizations with Poor or Fair reputation may lead to loss of experienced employees, lower productivity, and increased hiring expenses.
#
# * These insights help management focus on strengthening company culture and employer branding to improve long-term employee retention.

# %% [markdown]
# #### Chart - 18

# %%
# Chart - 18 visualization code
plt.figure(figsize=(9,5))

ax = sns.countplot(
    data=df,
    x='Employee Recognition',
    hue='Attrition',
    palette='mako'
)

# Add count labels
for container in ax.containers:
    ax.bar_label(container, fontsize=10)

plt.title('Employee Recognition vs Employee Attrition', fontsize=15)
plt.xlabel('Employee Recognition', fontsize=12)
plt.ylabel('Number of Employees', fontsize=12)
plt.legend(title='Attrition')

plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This chart was selected to analyze whether the level of **employee recognition influences employee attrition.**
#
# * It provides a clear comparison of employees who **stayed and left across different recognition levels**.
#
# * The chart helps determine if recognizing employees can improve retention and reduce employee turnover.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Employees receiving High or Very High recognition are more likely to stay with the company, indicating better employee retention.
#
# * Employees with Low recognition show the highest number of attrition cases, suggesting that lack of recognition may contribute to employees leaving.
#
# * The chart indicates that employee recognition plays an important role in improving job satisfaction and reducing attrition.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * Increasing employee recognition through rewards, appreciation, and performance acknowledgment can improve retention, motivation, and overall productivity.
#
# * Low employee recognition may result in higher attrition, leading to increased recruitment costs, loss of experienced employees, and reduced organizational performance.
#
# * These insights help organizations develop effective recognition programs to enhance employee engagement and reduce turnover.

# %% [markdown]
# #### Chart - 19

# %%
# Chart - 19 visualization code

plt.figure(figsize=(8,5))

sns.boxplot(
    data=df,
    x='Attrition',
    y='Distance from Home',
    palette='Set2'
)

plt.title('Distance from Home vs Employee Attrition', fontsize=15)
plt.xlabel('Employee Attrition', fontsize=12)
plt.ylabel('Distance from Home (km)', fontsize=12)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This box plot was chosen to compare the distribution of employees' distance from home for those who stayed and those who left the company.
#
# * It effectively shows the median, spread (IQR), and overall variation, making it easy to identify differences between the two groups.
#
# * The chart helps determine whether commuting distance is a potential factor influencing employee attrition.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Employees who left the company have a slightly higher median distance from home than employees who stayed.
#
# * The distribution of distance is wide for both groups, indicating that employees live at varying distances from the workplace.
#
# * The higher median for employees who left suggests that **longer commuting distance may contribute to increased employee attrition**, although it is not the only influencing factor.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# * The insights can help organizations reduce attrition by introducing **remote work, hybrid work, flexible working hours, or location-based hiring** for employees with long commutes.
#
# * A **longer commuting distance may increase employee stress and reduce job satisfaction**, which can contribute to higher employee turnover.
#
# * By addressing commuting challenges, companies can improve employee retention, productivity, and overall workforce satisfaction.

# %% [markdown]
# #### Chart - 20 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Select only numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64'])

# Correlation matrix
corr_matrix = numerical_cols.corr()

# Plot heatmap
plt.figure(figsize=(10,7))

sns.heatmap(
    corr_matrix,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5,
    square=True
)

plt.title("Correlation Heatmap of Numerical Features", fontsize=16, fontweight='bold')

plt.xticks(rotation=45, ha='right')
plt.yticks(rotation=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This **heatmap** was chosen to analyze the strength and direction of relationships between numerical features in the dataset.
#
# * It helps identify **positive, negative, or no correlation**, making it easier to understand how variables are related.
#
# * The chart supports feature selection by detecting relationships that may influence the employee attrition prediction model.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * **Age and Years at Company** show a **moderate positive correlation (0.54)**, indicating that **older employees generally have longer work experience** in the company.
#
# * **Years at Company and Company Tenure** also have a **moderate positive correlation (0.44)**, suggesting that **employees with more years in the company tend to have longer overall tenure**.
#
# * Most **other numerical features** have **very weak or nearly zero correlation**, indicating that they are largely independent and provide unique information for the prediction model.

# %% [markdown]
# #### Chart - 21 - Pair Plot

# %%
# Pair Plot visualization code
# Important numerical columns
pair_df = df[['Age',
              'Years at Company',
              'Monthly Income',
              'Distance from Home',
              'Company Tenure',
              'Attrition']]

# Pair Plot
sns.pairplot(
    pair_df,
    hue='Attrition',
    palette='Set2',
    diag_kind='hist',
    corner=True
)

plt.suptitle("Pair Plot of Numerical Features by Employee Attrition", y=1.02, fontsize=16)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# * This **pair plot **was chosen to visualize the **relationships among multiple numerical features simultaneously**.
#
# * It helps identify **patterns, trends, clusters, and potential outliers** while comparing employees who stayed and left.
#
# * The chart provides a comprehensive understanding of how numerical variables interact and supports feature selection for the attrition prediction model.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# * Most numerical features show weak or no strong linear relationship, indicating that each feature contributes unique information to the model.
#
# * Some features, such as **Age, Years at Company, and Company Tenure**, exhibit a **moderate positive relationship**, suggesting that experienced employees generally stay longer.
#
# * The distribution of employees who stayed and left overlaps across several features, indicating that employee attrition depends on a combination of factors rather than a single numerical variable.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Years at Company            0
# Job Role                    0
# Monthly Income              0
# Work-Life Balance           0
# Job Satisfaction            0
# Performance Rating          0
# Number of Promotions        0
# Overtime                    0
# Distance from Home          0
# Education Level             0
# Marital Status              0
# Number of Dependents        0
# Job Level                   0
# Company Size                0
# Company Tenure              0
# Remote Work                 0
# Leadership Opportunities    0
# Innovation Opportunities    0
# Company Reputation          0
# Employee Recognition        0
# Attrition                   0
# dtype: int64

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# **No missing value imputation technique** was used because the dataset contained **no missing values**. The missing values were checked using df.isnull().sum(), which confirmed that every column had complete data. Hence, no imputation was required.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Step 1 :
num_columns = df.select_dtypes(include = ['int64','float64']).columns
print(num_columns)

# Step 2 :
fig, axes = plt.subplots(4, 2, figsize=(8, 6))
axes = axes.flatten()

for i, col in enumerate(num_columns):
    axes[i].boxplot(df[col], vert=False)
    axes[i].set_title(col, fontsize=8)
    axes[i].tick_params(axis='both', labelsize=6)

for j in range(len(num_columns), len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout(pad=1)
plt.show()
# Out:
# Index(['Age', 'Years at Company', 'Monthly Income', 'Number of Promotions',
#        'Distance from Home', 'Number of Dependents', 'Company Tenure'],
#       dtype='object')

# %%
# Step 3 :
for col in num_columns:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(f"{col}: {len(outliers)} outliers")
# Out:
# Age: 0 outliers
# Years at Company: 273 outliers
# Monthly Income: 50 outliers
# Number of Promotions: 0 outliers
# Distance from Home: 0 outliers
# Number of Dependents: 0 outliers
# Company Tenure: 0 outliers

# %%
# Handling Outliers & Outlier treatments
df_outlier = df.copy()

# Columns having outliers
outlier_cols = ['Years at Company', 'Monthly Income']

for col in outlier_cols:
    Q1 = df_outlier[col].quantile(0.25)
    Q3 = df_outlier[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    # Cap the values
    df_outlier[col] = df_outlier[col].clip(lower=lower, upper=upper)

print("Outliers handled successfully.")
# Out:
# Outliers handled successfully.

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Outliers were detected using the **Interquartile Range (IQR) method** and treated using **IQR-based capping (Winsorization)**. Instead of removing records, extreme values were capped to the IQR limits, which reduced the impact of outliers **while preserving all employee records**. This approach improves model performance and m**aintains the integrity of the dataset**.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns

# Step 1 :
cat_cols = df.select_dtypes(include='object').columns
print(cat_cols)

# Step 2 :
# Encode target variable
df['Attrition'] = df['Attrition'].map({
    'Stayed': 1,
    'Left': 0
})

# Step 3 :

df = pd.get_dummies(
    df,
    columns=cat_cols.drop('Attrition'),
    drop_first=True,
    dtype=int
)

# Step 4 :
df.head()
# Out:
# Index(['Gender', 'Job Role', 'Work-Life Balance', 'Job Satisfaction',
#        'Performance Rating', 'Overtime', 'Education Level', 'Marital Status',
#        'Job Level', 'Company Size', 'Remote Work', 'Leadership Opportunities',
#        'Innovation Opportunities', 'Company Reputation',
#        'Employee Recognition', 'Attrition'],
#       dtype='object')
#    Age  Years at Company  Monthly Income  Number of Promotions  \
# 0   31                19            5390                     2
# 1   59                 4            5534                     3
# 2   24                10            8159                     0
# 3   36                 7            3989                     1
# 4   56                41            4821                     0
#
#    Distance from Home  Number of Dependents  Company Tenure  Attrition  \
# 0                  22                     0              89          1
# 1                  21                     3              21          1
# ...

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# 1. **Binary Encoding (Mapping) for the Target Variable**
#
# The target variable Attrition was encoded using binary mapping as:
#
# * Stayed = 1
# * Left = 0
#
# * Since the target variable contains only two categories, binary encoding is simple, efficient, and appropriate for binary classification problems.
# * It allows the model to easily distinguish between employees who stayed and those who left the company.
#
# 2. **One-Hot Encoding for Feature Variables**
#
# All remaining categorical feature columns were encoded using One-Hot Encoding with drop_first=True.
#
# This technique was chosen because:
#
# * It converts categorical values into numerical binary columns required by machine learning algorithms.
#
# * It does not introduce any artificial ordering among categories, making it suitable for nominal variables such as Gender, Job Role, Marital Status, Company Size, and Remote Work.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords

# %%
# Remove White spaces

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features


# Employee ID was removed because it is a unique identifier and does not contribute to prediction.

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting

X = df.drop('Attrition', axis=1)
y = df['Attrition']

print('Shape of X : ',X.shape)
print("Shape of y : ",y.shape)
# Out:
# Shape of X :  (59598, 41)
# Shape of y :  (59598,)

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Feature selection was performed by first removing the **Employee ID** column because it is a unique identifier and does not contribute to predicting employee attrition. After that, the **target variable (Attrition)** was separated from the input features by creating **X (independent variables)** and **y (dependent variable)**.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# Based on domain knowledge and exploratory data analysis, the following features were considered important because they are likely to influence an employee's decision to stay or leave the company:
#
# * **Years at Company**– Employees with very short or very long tenure may have different attrition patterns.
#
# * **Monthly Income** – Salary is a major factor affecting employee retention.
#
# * **Job Satisfaction** – Employees with lower job satisfaction are more likely to leave.
#
# * **Work-Life Balance** – Poor work-life balance can increase the likelihood of attrition.
#
# * **Overtime** – Employees working overtime frequently may experience stress and burnout.
#
# * **Number of Promotions** – Limited career growth opportunities may lead to higher attrition.
#
# * **Leadership Opportunities** – Better leadership opportunities encourage employees to stay.
#
# * **Employee Recognition** – Employees who receive recognition are generally more engaged and less likely to leave.
#
# * **Company Reputation** – Employees tend to remain longer in organizations with a positive reputation.
#
# * **Remote Work** – Flexible work arrangements can positively influence employee retention.

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# **No, dimensionality reduction** was not required for this project. After preprocessing and encoding, the dataset contained a manageable number of features (41), which can be efficiently handled by the selected machine learning algorithms. Since the dataset also contains a large number of observations, computational efficiency was not a concern.

# %%
# DImensionality Reduction (If needed)

# Dimensionality Reduction was not applied because the dataset has a manageable number
# of features and maintaining feature interpretability is important for this project.

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# No dimensionality reduction technique was applied in this project. Techniques such as Principal Component Analysis (PCA) were not used because the dataset contains a manageable number of features, and the selected machine learning models can efficiently handle them.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.

from sklearn.model_selection import train_test_split

X_train, X_test, y_train , y_test = train_test_split(
    X,y,test_size=0.20,random_state=42,stratify=y
)

print("Training Features Shape :",X_train.shape)
print("Testing Features Shape :",X_test.shape)
print("Training Features Shape :",y_train.shape)
print("Testing Features Shape :",y_train.shape)
# Out:
# Training Features Shape : (47678, 41)
# Testing Features Shape : (11920, 41)
# Training Features Shape : (47678,)
# Testing Features Shape : (47678,)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# * The dataset was divided into **80% training data and 20% testing data** using the **train_test_split() function**.
#
# * An 80:20 split was chosen because it provides a **good balance between model learning and performance evaluation**. The training set contains enough data for the model to **learn meaningful patterns**, while the testing set provides sufficient **unseen data to evaluate the model's generalization ability**.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1 - Logistic Regression

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# ML Model - 1 Implementation

from sklearn.linear_model import LogisticRegression

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    classification_report,
    roc_auc_score,
    RocCurveDisplay
)

# Fit the Algorithm
lr = LogisticRegression(random_state=42, max_iter=1000)
lr.fit(X_train, y_train)

# ===========================
# Train Accuracy
# ===========================
train_accuracy = lr.score(X_train, y_train)
print("Train Accuracy :", train_accuracy)
print()

# Predict on the model
y_pred_lr = lr.predict(X_test)
y_prob_lr = lr.predict_proba(X_test)[:,1]

# ===========================
# Test Accuracy
# ===========================
test_accuracy = lr.score(X_test, y_test)
print("Test Accuracy :", test_accuracy)
print()

# Evaluation Metrics
print("Precision :", precision_score(y_test, y_pred_lr))
print()

print("Recall :", recall_score(y_test, y_pred_lr))
print()

print("F1 Score :", f1_score(y_test, y_pred_lr))
print()

cm = confusion_matrix(y_test, y_pred_lr)
print("Confusion Matrix")
print(cm)
print()

print("Classification Report")
print(classification_report(y_test, y_pred_lr))
# Out:
# Train Accuracy : 0.7513528252023994
#
# Test Accuracy : 0.7500838926174497
#
# Precision : 0.7595559080095162
#
# Recall : 0.7659948816378759
#
# F1 Score : 0.7627618061638927
#
# Confusion Matrix
# [[4152 1516]
#  [1463 4789]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.74      5668
#            1       0.76      0.77      0.76      6252
#
#     accuracy                           0.75     11920
#    macro avg       0.75      0.75      0.75     11920
# weighted avg       0.75      0.75      0.75     11920

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

metrics = [
    'Train Accuracy',
    'Test Accuracy',
    'Precision',
    'Recall',
    'F1 Score'
]

scores = [
    train_accuracy,
    test_accuracy,
    precision_score(y_test, y_pred_lr),
    recall_score(y_test, y_pred_lr),
    f1_score(y_test, y_pred_lr)
]

# Set2 color palette
colors = sns.color_palette("Set2", len(metrics))

plt.figure(figsize=(8,5))

bars = plt.bar(metrics, scores, color=colors)

plt.title("Logistic Regression Evaluation Metric Score Chart", fontsize=14)
plt.xlabel("Evaluation Metrics", fontsize=12)
plt.ylabel("Score", fontsize=12)
plt.ylim(0,1)

# No grid
plt.grid(False)

# Display values on bars
for bar in bars:
    plt.text(
        bar.get_x() + bar.get_width()/2,
        bar.get_height() + 0.01,
        f'{bar.get_height():.2f}',
        ha='center',
        fontsize=10
    )

plt.show()

# %% [markdown]
# The Logistic Regression model was used as the baseline classifier to predict employee attrition. It achieved a training accuracy of 75.14% and a testing accuracy of 75.01%, indicating that the model is well-fitted. The model also obtained a precision of 75.96%, recall of 76.60%, and F1-score of 76.28%, showing balanced classification performance. Based on the evaluation metric score chart, Logistic Regression provides reliable predictions and serves as a good baseline for comparison with other machine learning models.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

from sklearn.model_selection import GridSearchCV

# Hyperparameter Grid
param_grid = {
    'C': [0.01, 0.1, 1, 10],
    'solver': ['liblinear', 'lbfgs'],
    'max_iter': [500, 1000]
}

# GridSearchCV with 5-Fold Cross Validation
grid_search = GridSearchCV(
    estimator=LogisticRegression(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Fit the Algorithm
grid_search.fit(X_train, y_train)

# Best Model
best_lr = grid_search.best_estimator_

# Predict on the model
y_pred_best = best_lr.predict(X_test)

# Train Accuracy
train_accuracy = best_lr.score(X_train, y_train)

# Test Accuracy
test_accuracy = best_lr.score(X_test, y_test)

print("Best Parameters :", grid_search.best_params_)
print()

print("Best Cross Validation Accuracy :", grid_search.best_score_)
print()

print("Train Accuracy :", train_accuracy)
print()

print("Test Accuracy :", test_accuracy)
print()

print("Precision :", precision_score(y_test, y_pred_best))
print()

print("Recall :", recall_score(y_test, y_pred_best))
print()

print("F1 Score :", f1_score(y_test, y_pred_best))
print()

print("Confusion Matrix")
cm = confusion_matrix(y_test, y_pred_best)
print(cm)
print()

print("Classification Report")
print(classification_report(y_test, y_pred_best))
# Out:
# Best Parameters : {'C': 0.1, 'max_iter': 500, 'solver': 'lbfgs'}
#
# Best Cross Validation Accuracy : 0.7508284934874341
#
# Train Accuracy : 0.7512689290658165
#
# Test Accuracy : 0.750251677852349
#
# Precision : 0.7597145122918318
#
# Recall : 0.7661548304542546
#
# F1 Score : 0.7629210798757665
#
# Confusion Matrix
# [[4153 1515]
#  [1462 4790]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.74      5668
#            1       0.76      0.77      0.76      6252
#
#     accuracy                           0.75     11920
#    macro avg       0.75      0.75      0.75     11920
# weighted avg       0.75      0.75      0.75     11920

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# **GridSearchCV** was used as the **hyperparameter optimization technique** for the **Logistic Regression model**. It systematically evaluates all possible combinations of the selected hyperparameters using **5-fold Cross Validation** and identifies the combination that provides the **highest validation accuracy**.
#
# The following hyperparameters were tuned:
#
# * C (Regularization Strength)
# * Solver
# * Max Iterations (max_iter)

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, a slight improvement was observed after applying GridSearchCV with 5-fold Cross Validation. The optimized model achieved a slightly higher test accuracy (75.03%) along with minor improvements in precision, recall, and F1-score. The close values of training and testing accuracy indicate that the model is well-generalized and performs consistently on unseen data. The updated evaluation metric score chart reflects these improvements.

# %% [markdown]
# ### ML Model - 2 : K-Nearest Neighbors (KNN)

# %%
# ML Model - 2 Implementation

from sklearn.neighbors import KNeighborsClassifier

# Fit the Algorithm
knn = KNeighborsClassifier(n_neighbors=5)

knn.fit(X_train, y_train)

train_accuracy = knn.score(X_train, y_train)

print("Train Accuracy :", train_accuracy)
print()

# Predict on the model
y_pred_knn = knn.predict(X_test)

test_accuracy = knn.score(X_test, y_test)

print("Test Accuracy :", test_accuracy)
print()

# Evaluation Metrics
print("Precision :", precision_score(y_test, y_pred_knn))
print()

print("Recall :", recall_score(y_test, y_pred_knn))
print()

print("F1 Score :", f1_score(y_test, y_pred_knn))
print()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_knn)

print("Confusion Matrix")
print(cm)
print()

# Classification Report
print("Classification Report")
print(classification_report(y_test, y_pred_knn))
# Out:
# Train Accuracy : 0.7957758295230505
#
# Test Accuracy : 0.673238255033557
#
# Precision : 0.6945682681195311
#
# Recall : 0.6729046705054382
#
# F1 Score : 0.6835648712324316
#
# Confusion Matrix
# [[3818 1850]
#  [2045 4207]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.65      0.67      0.66      5668
#            1       0.69      0.67      0.68      6252
#
#     accuracy                           0.67     11920
#    macro avg       0.67      0.67      0.67     11920
# weighted avg       0.67      0.67      0.67     11920

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

colors = sns.color_palette("Set2", len(metrics))

plt.figure(figsize=(8,5))

bars = plt.bar(metrics, scores, color=colors)

plt.title("KNN Evaluation Metric Score Chart")
plt.xlabel("Evaluation Metrics")
plt.ylabel("Score")
plt.ylim(0,1)

plt.grid(False)

for bar in bars:
    plt.text(
        bar.get_x()+bar.get_width()/2,
        bar.get_height()+0.01,
        f"{bar.get_height():.2f}",
        ha='center'
    )

plt.show()

# %% [markdown]
# The K-Nearest Neighbors (KNN) algorithm was implemented to classify employee attrition. KNN is a distance-based supervised learning algorithm that predicts the class of a new observation based on the majority class of its nearest neighbors. Since KNN relies on distance calculations, feature scaling was performed before training the model.
#
# The model achieved a **training accuracy of 79.58%** and a **testing accuracy of 67.32%**. The large difference between the training and testing accuracy indicates that the model is overfitting and does not generalize well to unseen data.
#
# The model achieved a **precision of 69.46%**, **recall of 67.29%,** and an **F1-score of 68.36%**. **Compared to Logistic Regression, KNN produced lower evaluation metrics**, suggesting that it is less effective for this employee attrition dataset.
#
# Overall, the evaluation metric score chart shows that **KNN did not perform as well as Logistic Regression** and requires hyperparameter tuning to improve its generalization performance.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 2 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)


# Hyperparameter Grid
param_grid = {
    'n_neighbors': [3, 5, 7, 9, 11],
    'weights': ['uniform', 'distance'],
    'metric': ['euclidean', 'manhattan']
}

# GridSearchCV with 5-Fold Cross Validation
grid_search = GridSearchCV(
    estimator=KNeighborsClassifier(),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Fit the Algorithm
grid_search.fit(X_train, y_train)

# Best Model
best_knn = grid_search.best_estimator_

# Prediction
y_pred_best = best_knn.predict(X_test)

train_accuracy = best_knn.score(X_train, y_train)
test_accuracy = best_knn.score(X_test, y_test)

print("Best Parameters :", grid_search.best_params_)
print()

print("Best Cross Validation Accuracy :", grid_search.best_score_)
print()

print("Train Accuracy :", train_accuracy)
print()

print("Test Accuracy :", test_accuracy)
print()

print("Precision :", precision_score(y_test, y_pred_best))
print()

print("Recall :", recall_score(y_test, y_pred_best))
print()

print("F1 Score :", f1_score(y_test, y_pred_best))
print()

cm = confusion_matrix(y_test, y_pred_best)

print("Confusion Matrix")
print(cm)
print()

print("Classification Report")
print(classification_report(y_test, y_pred_best))
# Out:
# Best Parameters : {'metric': 'manhattan', 'n_neighbors': 11, 'weights': 'distance'}
#
# Best Cross Validation Accuracy : 0.6993790296611213
#
# Train Accuracy : 1.0
#
# Test Accuracy : 0.697734899328859
#
# Precision : 0.7214512623307139
#
# Recall : 0.6901791426743442
#
# F1 Score : 0.705468813864138
#
# Confusion Matrix
# [[4002 1666]
#  [1937 4315]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69      5668
#            1       0.72      0.69      0.71      6252
#
#     accuracy                           0.70     11920
#    macro avg       0.70      0.70      0.70     11920
# weighted avg       0.70      0.70      0.70     11920

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# **GridSearchCV** was used as the **hyperparameter optimization technique** along with **5-fold Cross Validation** to optimize the K-Nearest Neighbors (KNN) model. It systematically evaluated different combinations of n_neighbors, weights, and distance metrics to determine the best-performing configuration. The optimal parameters obtained were **n_neighbors = 11**, **weights = 'distance'**, and **metric = 'manhattan'**. This technique was chosen because it performs an exhaustive search over the specified parameter values and selects the combination that achieves the highest cross-validation accuracy, resulting in a better-performing model.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# **Yes**, the **KNN model** showed an improvement after applying **GridSearchCV** with **5-fold Cross Validation**. The optimized model increased the **test accuracy** from **67.32% to 69.77%**. Improvements were also observed in **precision (69.46% to 72.15%)**, **recall (67.29% to 69.02%)**, and **F1-score (68.36% to 70.55%)**, indicating better predictive performance.
#
# However, the **training accuracy reached 100%**, while the **testing accuracy remained 69.77%**, indicating that the **KNN model is still overfitting the training data**. Although hyperparameter tuning improved the model's performance on unseen data, Logistic Regression continues to provide better generalization for this dataset.

# %% [markdown]
# ### ML Model - 3 : Naive Bayes

# %%
# ML Model - 3 Implementation

from sklearn.naive_bayes import GaussianNB

# Fit the Algorithm
nb = GaussianNB()

nb.fit(X_train, y_train)

train_accuracy = nb.score(X_train, y_train)

print("Train Accuracy :", train_accuracy)
print()

# Predict on the model
y_pred_nb = nb.predict(X_test)

test_accuracy = nb.score(X_test, y_test)

print("Test Accuracy :", test_accuracy)
print()

# Evaluation Metrics
print("Precision :", precision_score(y_test, y_pred_nb))
print()

print("Recall :", recall_score(y_test, y_pred_nb))
print()

print("F1 Score :", f1_score(y_test, y_pred_nb))
print()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_nb)

print("Confusion Matrix")
print(cm)
print()

# Classification Report
print("Classification Report")
print(classification_report(y_test, y_pred_nb))
# Out:
# Train Accuracy : 0.7251982046226771
#
# Test Accuracy : 0.7231543624161074
#
# Precision : 0.7567849686847599
#
# Recall : 0.6957773512476008
#
# F1 Score : 0.725
#
# Confusion Matrix
# [[4270 1398]
#  [1902 4350]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.69      0.75      0.72      5668
#            1       0.76      0.70      0.72      6252
#
#     accuracy                           0.72     11920
#    macro avg       0.72      0.72      0.72     11920
# weighted avg       0.73      0.72      0.72     11920

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

colors = sns.color_palette("viridis", len(metrics))
plt.figure(figsize=(8,5))

bars = plt.bar(metrics, scores, color=colors)

plt.title("Naive Bayes Evaluation Metric Score Chart")
plt.xlabel("Evaluation Metrics")
plt.ylabel("Score")
plt.ylim(0,1)

plt.grid(False)

for bar in bars:
    plt.text(
        bar.get_x()+bar.get_width()/2,
        bar.get_height()+0.01,
        f"{bar.get_height():.2f}",
        ha='center'
    )

plt.show()

# %% [markdown]
# The **Gaussian Naive Bayes algorithm** was implemented to predict employee attrition. Naive Bayes is a probabilistic supervised learning algorithm based on Bayes' Theorem and assumes that all features are conditionally independent given the target class. It is simple, computationally efficient, and performs well on many classification problems.
#
# The model achieved a **training accuracy of 72.52%** and a **testing accuracy of 72.32%**. The very small difference between the training and testing accuracy indicates that the **model generalizes well to unseen data and does not suffer from overfitting or underfitting**.
#
# The model also achieved a **precision of 75.68%**, **recall of 69.58%**, and an **F1-score of 72.50%**, indicating balanced classification performance. The evaluation metric score chart demonstrates that the Naive Bayes model provides stable and consistent predictions for employee attrition.
#
# Overall, although Naive Bayes performed well and showed good generalization, its **testing accuracy was slightly lower than Logistic Regression**, making Logistic Regression the better-performing model for this dataset.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

param_grid = {
    'var_smoothing': [1e-12, 1e-11, 1e-10, 1e-9, 1e-8]
}

grid_search = GridSearchCV(
    GaussianNB(),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

grid_search.fit(X_train, y_train)

best_nb = grid_search.best_estimator_

y_pred_best = best_nb.predict(X_test)

train_accuracy = best_nb.score(X_train, y_train)
test_accuracy = best_nb.score(X_test, y_test)

print("Best Parameters :", grid_search.best_params_)
print()

print("Best Cross Validation Accuracy :", grid_search.best_score_)
print()

print("Train Accuracy :", train_accuracy)
print()

print("Test Accuracy :", test_accuracy)
print()

print("Precision :", precision_score(y_test, y_pred_best))
print()

print("Recall :", recall_score(y_test, y_pred_best))
print()

print("F1 Score :", f1_score(y_test, y_pred_best))
print()

cm = confusion_matrix(y_test, y_pred_best)

print("Confusion Matrix")
print(cm)
print()

print("Classification Report")
print(classification_report(y_test, y_pred_best))
# Out:
# Best Parameters : {'var_smoothing': 1e-12}
#
# Best Cross Validation Accuracy : 0.7250513253889767
#
# Train Accuracy : 0.7251982046226771
#
# Test Accuracy : 0.7231543624161074
#
# Precision : 0.7567849686847599
#
# Recall : 0.6957773512476008
#
# F1 Score : 0.725
#
# Confusion Matrix
# [[4270 1398]
#  [1902 4350]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.69      0.75      0.72      5668
#            1       0.76      0.70      0.72      6252
#
#     accuracy                           0.72     11920
#    macro avg       0.72      0.72      0.72     11920
# weighted avg       0.73      0.72      0.72     11920

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# **GridSearchCV with 5-fold Cross Validation** was used to optimize the Gaussian Naive Bayes model. The **hyperparameter var_smoothing** was tuned by evaluating multiple values, and the **optimal value selected was 1e-12**. GridSearchCV systematically searches all specified parameter combinations and selects the one with the highest cross-validation accuracy. This technique improves the reliability of the model by identifying the most suitable hyperparameter configuration for the dataset.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# After applying **GridSearchCV with 5-fold Cross Validation**, no significant improvement was observed in the **performance of the Gaussian Naive Bayes model**. The **training accuracy (72.52%)**, **testing accuracy (72.32%)**, **precision (75.68%)**, **recall (69.58%)**, and **F1-score (72.50%)** remained almost unchanged compared to the baseline model.
#
# This indicates that the default configuration of the Gaussian Naive Bayes model was already close to optimal for this dataset. Although **hyperparameter tuning did not improve the evaluation metrics**, it confirmed that the selected value of var_smoothing = 1e-12 is appropriate and that the **model is stable and well-generalized**.

# %% [markdown]
# ### ML Model - 4 : Decision Tree

# %%
# ML Model - 4 Implementation

from sklearn.tree import DecisionTreeClassifier

# Fit the Algorithm
dt = DecisionTreeClassifier(random_state=42)

dt.fit(X_train, y_train)

train_accuracy = dt.score(X_train, y_train)

print("Train Accuracy :", train_accuracy)
print()

# Predict on the model
y_pred_dt = dt.predict(X_test)

test_accuracy = dt.score(X_test, y_test)

print("Test Accuracy :", test_accuracy)
print()

# Evaluation Metrics
print("Precision :", precision_score(y_test, y_pred_dt))
print()

print("Recall :", recall_score(y_test, y_pred_dt))
print()

print("F1 Score :", f1_score(y_test, y_pred_dt))
print()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_dt)

print("Confusion Matrix")
print(cm)
print()

# Classification Report
print("Classification Report")
print(classification_report(y_test, y_pred_dt))
# Out:
# Train Accuracy : 1.0
#
# Test Accuracy : 0.6721476510067114
#
# Precision : 0.686268277177368
#
# Recall : 0.6906589891234804
#
# F1 Score : 0.6884566326530612
#
# Confusion Matrix
# [[3694 1974]
#  [1934 4318]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.66      0.65      0.65      5668
#            1       0.69      0.69      0.69      6252
#
#     accuracy                           0.67     11920
#    macro avg       0.67      0.67      0.67     11920
# weighted avg       0.67      0.67      0.67     11920

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

colors = sns.color_palette("magma", len(metrics))

plt.figure(figsize=(8,5))

bars = plt.bar(metrics, scores, color=colors)

plt.title("Decision Tree Evaluation Metric Score Chart")
plt.xlabel("Evaluation Metrics")
plt.ylabel("Score")
plt.ylim(0,1)

plt.grid(False)

for bar in bars:
    plt.text(
        bar.get_x()+bar.get_width()/2,
        bar.get_height()+0.01,
        f"{bar.get_height():.2f}",
        ha="center"
    )

plt.show()

# %% [markdown]
# **The Decision Tree Classifier** was implemented to predict employee attrition. Decision Tree is a supervised learning algorithm that recursively splits the data based on feature values to create decision rules for classification.
#
# The model achieved a **training accuracy of 100%,** but the **testing accuracy was only 67.21%**. The large difference between the training and testing accuracy indicates that the **model is highly overfitting**. This means the model has learned the training data very well but is unable to generalize effectively to unseen data.
#
# The model obtained a **precision of 68.63%**, **recall of 69.07%**, and an **F1-score of 68.85%**. Although the model correctly classified many observations, its **overall performance is lower than Logistic Regression and Naive Bayes**. Therefore, hyperparameter tuning is required to reduce overfitting and improve the model's generalization performance.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 4 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [5, 10, 15, 20, None],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

grid_search = GridSearchCV(
    DecisionTreeClassifier(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Fit the Algorithm
grid_search.fit(X_train, y_train)

# Best Model
best_dt = grid_search.best_estimator_

# Prediction
y_pred_best = best_dt.predict(X_test)

# Evaluation
train_accuracy = best_dt.score(X_train, y_train)
test_accuracy = best_dt.score(X_test, y_test)

print("Best Parameters :", grid_search.best_params_)
print()

print("Best Cross Validation Accuracy :", grid_search.best_score_)
print()

print("Train Accuracy :", train_accuracy)
print()

print("Test Accuracy :", test_accuracy)
print()

print("Precision :", precision_score(y_test, y_pred_best))
print()

print("Recall :", recall_score(y_test, y_pred_best))
print()

print("F1 Score :", f1_score(y_test, y_pred_best))
print()

cm = confusion_matrix(y_test, y_pred_best)

print("Confusion Matrix")
print(cm)
print()

print("Classification Report")
print(classification_report(y_test, y_pred_best))
# Out:
# Best Parameters : {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10}
#
# Best Cross Validation Accuracy : 0.7251352575991665
#
# Train Accuracy : 0.7552749695876505
#
# Test Accuracy : 0.7246644295302014
#
# Precision : 0.7479131886477463
#
# Recall : 0.7165706973768394
#
# F1 Score : 0.7319065512171213
#
# Confusion Matrix
# [[4158 1510]
#  [1772 4480]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.70      0.73      0.72      5668
#            1       0.75      0.72      0.73      6252
#
#     accuracy                           0.72     11920
#    macro avg       0.72      0.73      0.72     11920
# weighted avg       0.73      0.72      0.72     11920

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# **GridSearchCV with 5-fold Cross Validation** was used to **optimize the Decision Tree model.** The algorithm evaluated different combinations of **criterion, max_depth, min_samples_split, and min_samples_leaf** to identify the best-performing configuration.
#
# The optimal hyperparameters obtained were:
#
# * Criterion: Entropy
# * Max Depth: 10
# * Minimum Samples Split: 10
# * Minimum Samples Leaf: 4
#
# GridSearchCV was selected because it performs an exhaustive search over all specified hyperparameter combinations and selects the model with the highest cross-validation accuracy. This helps reduce overfitting and improves the model's ability to generalize to unseen data.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# **Yes**, a significant improvement was observed after applying GridSearchCV with 5-fold Cross Validation. Before tuning, **the Decision Tree model was highly overfitting**, with **100% training accuracy** and only **67.21% testing accuracy**.
#
# After hyperparameter tuning, the **training accuracy decreased to 75.53%**, while the **testing accuracy improved to 72.47%**, indicating much better generalization. Improvements were also observed in **precision (68.63% to 74.79%)**, **recall (69.07% to 71.66%)**, and **F1-score (68.85% to 73.19%)**.
#
# The updated evaluation metric score chart confirms that hyperparameter tuning successfully reduced overfitting and improved the overall predictive performance of the Decision Tree model.

# %% [markdown]
# ### ML Model - 5 : Random Forest

# %%
# ML Model - 5 Implementation

from sklearn.ensemble import RandomForestClassifier

# Fit the Algorithm
rf = RandomForestClassifier(random_state=42)

rf.fit(X_train, y_train)
train_accuracy = rf.score(X_train, y_train)

print("Train Accuracy :", train_accuracy)
print()

# Predict on the model
y_pred_rf = rf.predict(X_test)

test_accuracy = rf.score(X_test, y_test)

print("Test Accuracy :", test_accuracy)
print()

# Evaluation Metrics
print("Precision :", precision_score(y_test, y_pred_rf))
print()

print("Recall :", recall_score(y_test, y_pred_rf))
print()

print("F1 Score :", f1_score(y_test, y_pred_rf))
print()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_rf)

print("Confusion Matrix")
print(cm)
print()

# Classification Report
print(classification_report(y_test, y_pred_rf))
# Out:
# Train Accuracy : 1.0
#
# Test Accuracy : 0.7472315436241611
#
# Precision : 0.758252272364854
#
# Recall : 0.760556621880998
#
# F1 Score : 0.7594026990337779
#
# Confusion Matrix
# [[4152 1516]
#  [1497 4755]]
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73      5668
#            1       0.76      0.76      0.76      6252
#
#     accuracy                           0.75     11920
#    macro avg       0.75      0.75      0.75     11920
# weighted avg       0.75      0.75      0.75     11920

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

colors = sns.color_palette("Spectral", len(metrics))

plt.figure(figsize=(8,5))

bars = plt.bar(metrics, scores, color=colors)

plt.title("Random Forest Evaluation Metric Score Chart")
plt.xlabel("Evaluation Metrics")
plt.ylabel("Score")
plt.ylim(0,1)

plt.grid(False)

for bar in bars:
    plt.text(
        bar.get_x()+bar.get_width()/2,
        bar.get_height()+0.01,
        f"{bar.get_height():.2f}",
        ha="center"
    )

plt.show()

# %% [markdown]
# The **Random Forest Classifier** was implemented to predict employee attrition. Random Forest is an ensemble learning algorithm that combines multiple decision trees using the bagging technique. The final prediction is obtained through majority voting, which generally improves accuracy and reduces variance compared to a single Decision Tree.
#
# The model achieved a **training accuracy of 100%** and a **testing accuracy of 74.72%**. Although the testing accuracy is one of the highest among all the implemented models, the large difference between the training and testing accuracy indicates that the model is overfitting the training data.
#
# The model also achieved a **precision of 75.83%**, **recall of 76.06%**, and an **F1-score of 75.94%**, demonstrating strong classification performance. The evaluation metric score chart shows that the Random Forest model performs well; however, hyperparameter tuning is required to reduce overfitting and improve generalization.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 5 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [10, 20, None],
    'min_samples_split': [2, 5],
    'min_samples_leaf': [1, 2],
    'max_features': ['sqrt', 'log2']
}

grid_search = GridSearchCV(
    RandomForestClassifier(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Fit the Algorithm
grid_search.fit(X_train, y_train)

# Best Model
best_rf = grid_search.best_estimator_

# Prediction
y_pred_best = best_rf.predict(X_test)

# Evaluation
train_accuracy = best_rf.score(X_train, y_train)
test_accuracy = best_rf.score(X_test, y_test)

print("Best Parameters :", grid_search.best_params_)
print()

print("Best Cross Validation Accuracy :", grid_search.best_score_)
print()

print("Train Accuracy :", train_accuracy)
print()

print("Test Accuracy :", test_accuracy)
print()

print("Precision :", precision_score(y_test, y_pred_best))
print()

print("Recall :", recall_score(y_test, y_pred_best))
print()

print("F1 Score :", f1_score(y_test, y_pred_best))
print()

cm = confusion_matrix(y_test, y_pred_best)

print("Confusion Matrix")
print(cm)
print()

print("Classification Report")
print(classification_report(y_test, y_pred_best))
# Out:
# Best Parameters : {'max_depth': None, 'max_features': 'log2', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 200}
#
# Best Cross Validation Accuracy : 0.7504509019226234
#
# Train Accuracy : 0.987289735307689
#
# Test Accuracy : 0.749496644295302
#
# Precision : 0.7575709779179811
#
# Recall : 0.7682341650671785
#
# F1 Score : 0.7628653113087674
#
# Confusion Matrix
# [[4131 1537]
#  [1449 4803]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73      5668
#            1       0.76      0.77      0.76      6252
#
#     accuracy                           0.75     11920
#    macro avg       0.75      0.75      0.75     11920
# weighted avg       0.75      0.75      0.75     11920

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# **GridSearchCV with 5-fold Cross Validation** was used to optimize the Random Forest Classifier. Different combinations of **n_estimators, max_depth, min_samples_split, min_samples_leaf, and max_features** were evaluated to identify the optimal model configuration.
#
# The best hyperparameters obtained were:
#
# * n_estimators = 200
# * max_depth = None
# * min_samples_split = 2
# * min_samples_leaf = 2
# * max_features = 'log2'
#
# GridSearchCV was selected because it performs an exhaustive search over all specified parameter combinations and selects the model with the highest cross-validation accuracy. This helps improve predictive performance and provides a more reliable model.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# **Yes**, a slight improvement was observed after applying **GridSearchCV with 5-fold Cross Validation**. The optimized Random Forest model increased the testing accuracy from **74.72% to 74.95%**. Improvements were also observed in recall and F1-score, indicating better predictive performance.
#
# Although the training accuracy remained high (98.73%), it decreased slightly compared to the initial model, suggesting a small reduction in overfitting. The updated evaluation metric score chart confirms that the tuned Random Forest model performs slightly better while maintaining strong classification performance.

# %% [markdown]
# ### ML Model - 6 : Support Vector Machine (SVM)

# %%
# ML Model - 6 Implementation

from sklearn.svm import SVC

# Fit the Algorithm
svm = SVC(random_state=42)

svm.fit(X_train, y_train)

train_accuracy = svm.score(X_train, y_train)

print("Train Accuracy :", train_accuracy)
print()

# Predict on the model
y_pred_svm = svm.predict(X_test)

test_accuracy = svm.score(X_test, y_test)

print("Test Accuracy :", test_accuracy)
print()

# Evaluation Metrics
print("Precision :", precision_score(y_test, y_pred_svm))
print()

print("Recall :", recall_score(y_test, y_pred_svm))
print()

print("F1 Score :", f1_score(y_test, y_pred_svm))
print()

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred_svm)

print("Confusion Matrix")
print(cm)
print()

print("Classification Report")
print(classification_report(y_test, y_pred_svm))
# Out:
# Train Accuracy : 0.8069969377910148
#
# Test Accuracy : 0.7480704697986578
#
# Precision : 0.7588019754659869
#
# Recall : 0.7618362124120281
#
# F1 Score : 0.7603160667251976
#
# Confusion Matrix
# [[4154 1514]
#  [1489 4763]]
#
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73      5668
#            1       0.76      0.76      0.76      6252
#
#     accuracy                           0.75     11920
#    macro avg       0.75      0.75      0.75     11920
# weighted avg       0.75      0.75      0.75     11920

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart

colors = sns.color_palette("Dark2", len(metrics))

plt.figure(figsize=(8,5))

bars = plt.bar(metrics, scores, color=colors)

plt.title("SVM Evaluation Metric Score Chart")
plt.xlabel("Evaluation Metrics")
plt.ylabel("Score")
plt.ylim(0,1)

plt.grid(False)

for bar in bars:
    plt.text(
        bar.get_x()+bar.get_width()/2,
        bar.get_height()+0.01,
        f"{bar.get_height():.2f}",
        ha='center'
    )

plt.show()

# %% [markdown]
# The **Support Vector Machine (SVM) classifier** was implemented to predict employee attrition. SVM is a supervised machine learning algorithm that identifies the optimal hyperplane to separate different classes while maximizing the margin between them. Since SVM is sensitive to feature scales, the input features were standardized before training the model.
#
# The model achieved a **training accuracy of 80.70%** and a **testing accuracy of 74.81%**. The relatively small difference between the training and testing accuracy indicates that the model generalizes well and does not suffer from significant overfitting.
#
# The model also achieved a **precision of 75.88%**, **recall of 76.18%**, and an **F1-score of 76.03%**, indicating balanced classification performance. Overall, the evaluation metric score chart shows that SVM provides strong predictive performance and is one of the best-performing models for this dataset.

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 6 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)

from sklearn.model_selection import GridSearchCV

param_grid = {
    'C': [0.1, 1, 10],
    'kernel': ['linear', 'rbf'],
    'gamma': ['scale', 'auto']
}

grid_search = GridSearchCV(
    SVC(random_state=42),
    param_grid=param_grid,
    cv=5,
    scoring='accuracy',
    n_jobs=-1
)

# Fit the Algorithm
grid_search.fit(X_train, y_train)

# Best Model
best_svm = grid_search.best_estimator_

# Prediction
y_pred_best = best_svm.predict(X_test)

# Evaluation
train_accuracy = best_svm.score(X_train, y_train)
test_accuracy = best_svm.score(X_test, y_test)

print("Best Parameters :", grid_search.best_params_)
print()

print("Best Cross Validation Accuracy :", grid_search.best_score_)
print()

print("Train Accuracy :", train_accuracy)
print()

print("Test Accuracy :", test_accuracy)
print()

print("Precision :", precision_score(y_test, y_pred_best))
print()

print("Recall :", recall_score(y_test, y_pred_best))
print()

print("F1 Score :", f1_score(y_test, y_pred_best))
print()

cm = confusion_matrix(y_test, y_pred_best)

print("Confusion Matrix")
print(cm)
print()

print("Classification Report")
print(classification_report(y_test, y_pred_best))

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
